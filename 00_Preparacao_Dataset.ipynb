# %%
#Instalando a biblioteca Dataset
# !pip install datasets

# %%
# Carrega o dataset de tweets em português do Hugging Face
from datasets import load_dataset

dataset = load_dataset("miguelribeirokk/crime_tweets_in_portuguese")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md: 0.00B [00:00, ?B/s]
# 61K_crime_tweets_portuguese.csv:   0%|          | 0.00/10.3M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/61715 [00:00<?, ? examples/s]

# %%
# Converte o dataset em um DataFrame (tabela) e mostra as primeiras linhas
import pandas as pd

df = pd.DataFrame(dataset['train'])
df.head()
# Out:
#    id                                               text  INSULT  \
# 0   1          gatilho c a praca sete amg so os assaltos  0.0250
# 1   2  na rodoviaria de sp nao aguardem proximo ao po...  0.0302
# 2   3  eu espero que a policia esteja treinada para i...  0.0261
# 3   4  assaltaram duas casas aqui na minha rua e agor...  0.0235
# 4   5  sim e importante a apuracao para mostrar que f...  0.0363
#
#    IDENTITY_ATTACK  SEVERE_TOXICITY  THREAT  PROFANITY  TOXICITY  POSITIVE  \
# 0           0.0188           0.0153  0.2921     0.0640    0.2381    0.0533
# 1           0.0041           0.0018  0.0062     0.0829    0.0590    0.0133
# 2           0.0188           0.0017  0.0070     0.0111    0.0476    0.1297
# 3           0.0224           0.0130  0.2567     0.0781    0.2396    0.0152
# 4           0.0060           0.0041  0.0232     0.0173    0.0895    0.0819
#
#    NEUTRAL  ...  ASSALTO  ROUBO  FURTO  ASSEDIO  SPUBLICA  HOMICIDIO  OUTRO  \
# ...

# %%
# Seleciona a coluna de texto (tweets), renomeia para "documento",
df_documentos = df[['text']].copy()

df_documentos.columns = ['documento']
df_documentos.insert(0, 'id', range(1, len(df_documentos) + 1))

df_documentos = df_documentos.head(50)

df_documentos.head()
# Out:
#    id                                          documento
# 0   1          gatilho c a praca sete amg so os assaltos
# 1   2  na rodoviaria de sp nao aguardem proximo ao po...
# 2   3  eu espero que a policia esteja treinada para i...
# 3   4  assaltaram duas casas aqui na minha rua e agor...
# 4   5  sim e importante a apuracao para mostrar que f...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_documentos.to_csv('/content/documentos.csv',
                     index=False,
                     encoding='utf-8',
                     sep=';')

# %%
# Lista os arquivos que estão na pasta /content do Colab
import os
os.listdir('/content')
# Out:
# ['.config', 'documentos.csv', 'drive', 'sample_data']

# %%
df_documentos = df[['text']].copy()

df_documentos.columns = ['documento']
df_documentos.insert(0, 'id', range(1, len(df_documentos) + 1))

df_documentos = df_documentos.head(50)

df_documentos.to_csv('/content/drive/MyDrive/Colab Notebooks/SRI/data/documentos.csv',
                     index=False,
                     encoding='utf-8',
                     sep=';')

# %%
df_teste = pd.read_csv('/content/documentos.csv', sep=';')
df_teste.shape
# Out:
# (50, 2)

# %%
with open('/content/drive/MyDrive/Colab Notebooks/SRI/data/documentos.csv', 'r', encoding='utf-8') as f:
    for i in range(3):
        print(f.readline())
# Out:
# id;documento
#
# 1;gatilho c a praca sete amg so os assaltos
#
# 2;na rodoviaria de sp nao aguardem proximo ao portao de embarque quase fui assaltada em marco pq n tinha essa maldade inves de ficar na praca de alimentacao la nao tem controle de quem vai embarcar ou nao so vao para o acesso de embarque uns 15 min que ja tera fila
